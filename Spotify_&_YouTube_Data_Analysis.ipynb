# %% [markdown]
# <a href="https://colab.research.google.com/github/Harshiit17/projects-1/blob/main/Spotify_%26_YouTube_Data_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Spotify & YouTube Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data = pd.read_csv("/content/Spotify_Youtube Dataset.csv")

# %%
data
# Out:
#       Unnamed: 0    Artist                                        Url_spotify  \
# 0              0  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 1              1  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 2              2  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 3              3  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# 4              4  Gorillaz  https://open.spotify.com/artist/3AA28KZvwAUcZu...
# ...          ...       ...                                                ...
# 5934        5934      Mase  https://open.spotify.com/artist/1wiBLzTI7z9RUw...
# 5935        5935      Mase  https://open.spotify.com/artist/1wiBLzTI7z9RUw...
# 5936        5936      Mase  https://open.spotify.com/artist/1wiBLzTI7z9RUw...
# 5937        5937      Mase  https://open.spotify.com/artist/1wiBLzTI7z9RUw...
# 5938        5938      Mase  https://open.spotify.com/artist/1wiBLzTI7z9RUw...
#
#                                                   Track  \
# 0                                        Feel Good Inc.
# 1                                       Rhinestone Eyes
# 2         New Gold (feat. Tame Impala and Bootie Brown)
# 3                                    On Melancholy Hill
# 4                                        Clint Eastwood
# ...                                                 ...
# 5934                                       Welcome Back
# 5935                        What You Want (feat. Total)
# 5936                   Lookin' at Me (feat. Puff Daddy)
# 5937           Breathe, Stretch, Shake (feat. P. Diddy)
# 5938  Take Me There - From "The Rugrats Movie" Sound...
#
#                                                  Album   Album_type  \
# 0                                           Demon Days        album
# 1                                        Plastic Beach        album
# 2        New Gold (feat. Tame Impala and Bootie Brown)       single
# 3                                        Plastic Beach        album
# 4                                             Gorillaz        album
# ...                                                ...          ...
# 5934                                      Welcome Back        album
# 5935                                          R&B Hits  compilation
# 5936                                      Harlem World        album
# 5937                                      Welcome Back        album
# 5938  Music From The Motion Picture: The Rugrats Movie  compilation
#
#                                        Uri  Danceability  Energy  Key  ...  \
# 0     spotify:track:0d28khcov6AiegSCpG5TuT         0.818   0.705    6  ...
# 1     spotify:track:1foMv2HQwfQ2vntFf9HFeG         0.676   0.703    8  ...
# 2     spotify:track:64dLd6rVqDLtkXFYrEUHIU         0.695   0.923    1  ...
# 3     spotify:track:0q6LuUqGLUiCPP1cbdwFs3         0.689   0.739    2  ...
# 4     spotify:track:7yMiX7n9SBvadzox8T5jzT         0.663   0.694   10  ...
# ...                                    ...           ...     ...  ...  ...
# 5934  spotify:track:2XQY54Im8VrO4sd2tAmiv4         0.764   0.744    1  ...
# 5935  spotify:track:2nqVVwUI2MJ7MaphpCF1P3         0.880   0.726   10  ...
# 5936  spotify:track:2dieHErJLwG7fOzD8WAtFO         0.743   0.516   11  ...
# 5937  spotify:track:5qjESLw4uzDNvG2V5QIoaS         0.567   0.711    1  ...
# 5938  spotify:track:4TQOC2AhsD96oPxAC6NB6w         0.401   0.872    0  ...
#
#                                       Url_youtube  \
# 0     https://www.youtube.com/watch?v=HyHNuVaZJ-k
# 1     https://www.youtube.com/watch?v=yYDmaexVHic
# 2     https://www.youtube.com/watch?v=qJa-VFwPpYA
# 3     https://www.youtube.com/watch?v=04mfKJWDSzI
# 4     https://www.youtube.com/watch?v=1V_xRb0x9aw
# ...                                           ...
# 5934  https://www.youtube.com/watch?v=vNey0PR46F4
# 5935  https://www.youtube.com/watch?v=5Whe1GUjtKE
# 5936  https://www.youtube.com/watch?v=AAriiyPQLPk
# 5937  https://www.youtube.com/watch?v=Xm5SHvSDMWU
# 5938  https://www.youtube.com/watch?v=CWOPYe3otpc
#
#                                                   Title  \
# 0            Gorillaz - Feel Good Inc. (Official Video)
# 1     Gorillaz - Rhinestone Eyes [Storyboard Film] (...
# 2     Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3        Gorillaz - On Melancholy Hill (Official Video)
# 4            Gorillaz - Clint Eastwood (Official Video)
# ...                                                 ...
# 5934         Mase - Welcome Back (Official Music Video)
# 5935  Mase [feat. Total] - What You Want (Official M...
# 5936  Ma$e, Diddy: Lookin' At Me (EXPLICIT) [UP.S 4K...
# 5937  Mase - Breath, Stretch, Shake (Official Music ...
# 5938  Take Me There- Mya ft. Blackstreet, Mase, Blin...
#
#                     Channel        Views      Likes  Comments  \
# 0                  Gorillaz  693555221.0  6220896.0  169907.0
# 1                  Gorillaz   72011645.0  1079128.0   31003.0
# 2                  Gorillaz    8435055.0   282142.0    7399.0
# 3                  Gorillaz  211754952.0  1788577.0   55229.0
# 4                  Gorillaz  618480958.0  6197318.0  155930.0
# ...                     ...          ...        ...       ...
# 5934  Bad Boy Entertainment    8197484.0    87436.0    5699.0
# 5935  Bad Boy Entertainment   19975260.0   165989.0    3642.0
# 5936   REMASTERED HIPHOPâª      14135.0      399.0      28.0
# 5937        MASE TELEVISION     612044.0     7570.0     511.0
# 5938          MrILovethe90s     980948.0    14763.0    1267.0
#
#                                             Description  Licensed  \
# 0     Official HD Video for Gorillaz' fantastic trac...      True
# 1     The official video for Gorillaz - Rhinestone E...      True
# 2     Gorillaz - New Gold ft. Tame Impala & Bootie B...      True
# 3     Follow Gorillaz online:\nhttp://gorillaz.com \...      True
# 4     The official music video for Gorillaz - Clint ...      True
# ...                                                 ...       ...
# 5934  Official Music Video for Mase - "Welcome Back"...      True
# 5935  Official Music Video for Mase [feat. Total] - ...      True
# 5936  SUPPORT/DONATE/REQUEST: https://paypal.me/REMA...     False
# 5937  Courtesy Of Bad Boy Entertainment/Fo' Reel Ent...     False
# 5938  take me there off the rugrats movie soundtrack...     False
#
#      official_video        Stream
# 0              True  1.040235e+09
# 1              True  3.100837e+08
# 2              True  6.306347e+07
# 3              True  4.346636e+08
# 4              True  6.172597e+08
# ...             ...           ...
# 5934           True  2.354820e+07
# 5935           True  1.309991e+07
# 5936          False  1.006187e+07
# 5937          False  8.180179e+06
# 5938          False  8.443052e+06
#
# [5939 rows x 28 columns]

# %%
data.columns                   # to show the names of columns of the dataframe
# Out:
# Index(['Unnamed: 0', 'Artist', 'Url_spotify', 'Track', 'Album', 'Album_type',
#        'Uri', 'Danceability', 'Energy', 'Key', 'Loudness', 'Speechiness',
#        'Acousticness', 'Instrumentalness', 'Liveness', 'Valence', 'Tempo',
#        'Duration_ms', 'Url_youtube', 'Title', 'Channel', 'Views', 'Likes',
#        'Comments', 'Description', 'Licensed', 'official_video', 'Stream'],
#       dtype='object')

# %%
data.info()                   # to get some basic information about the datset
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5939 entries, 0 to 5938
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Unnamed: 0        5939 non-null   int64
#  1   Artist            5939 non-null   object
#  2   Url_spotify       5939 non-null   object
#  3   Track             5939 non-null   object
#  4   Album             5939 non-null   object
#  5   Album_type        5939 non-null   object
#  6   Uri               5939 non-null   object
#  7   Danceability      5939 non-null   float64
#  8   Energy            5939 non-null   float64
#  9   Key               5939 non-null   int64
#  10  Loudness          5939 non-null   float64
#  11  Speechiness       5939 non-null   float64
#  12  Acousticness      5939 non-null   float64
#  13  Instrumentalness  5939 non-null   float64
#  14  Liveness          5939 non-null   float64
#  15  Valence           5939 non-null   float64
#  16  Tempo             5939 non-null   float64
#  17  Duration_ms       5939 non-null   int64
#  18  Url_youtube       5820 non-null   object
#  19  Title             5820 non-null   object
#  20  Channel           5820 non-null   object
#  21  Views             5820 non-null   float64
#  22  Likes             5793 non-null   float64
#  23  Comments          5793 non-null   float64
#  24  Description       5613 non-null   object
#  25  Licensed          5820 non-null   object
#  26  official_video    5820 non-null   object
#  27  Stream            5727 non-null   float64
# dtypes: float64(13), int64(3), object(12)
# memory usage: 1.3+ MB

# %%
# removing the columns from the dataframe

data.drop(columns = ['Unnamed: 0', 'Url_spotify', 'Uri', 'Url_youtube'], inplace = True)

# %%
data
# Out:
#         Artist                                              Track  \
# 0     Gorillaz                                     Feel Good Inc.
# 1     Gorillaz                                    Rhinestone Eyes
# 2     Gorillaz      New Gold (feat. Tame Impala and Bootie Brown)
# 3     Gorillaz                                 On Melancholy Hill
# 4     Gorillaz                                     Clint Eastwood
# ...        ...                                                ...
# 5934      Mase                                       Welcome Back
# 5935      Mase                        What You Want (feat. Total)
# 5936      Mase                   Lookin' at Me (feat. Puff Daddy)
# 5937      Mase           Breathe, Stretch, Shake (feat. P. Diddy)
# 5938      Mase  Take Me There - From "The Rugrats Movie" Sound...
#
#                                                  Album   Album_type  \
# 0                                           Demon Days        album
# 1                                        Plastic Beach        album
# 2        New Gold (feat. Tame Impala and Bootie Brown)       single
# 3                                        Plastic Beach        album
# 4                                             Gorillaz        album
# ...                                                ...          ...
# 5934                                      Welcome Back        album
# 5935                                          R&B Hits  compilation
# 5936                                      Harlem World        album
# 5937                                      Welcome Back        album
# 5938  Music From The Motion Picture: The Rugrats Movie  compilation
#
#       Danceability  Energy  Key  Loudness  Speechiness  Acousticness  ...  \
# 0            0.818   0.705    6    -6.679       0.1770      0.008360  ...
# 1            0.676   0.703    8    -5.815       0.0302      0.086900  ...
# 2            0.695   0.923    1    -3.930       0.0522      0.042500  ...
# 3            0.689   0.739    2    -5.810       0.0260      0.000015  ...
# 4            0.663   0.694   10    -8.627       0.1710      0.025300  ...
# ...            ...     ...  ...       ...          ...           ...  ...
# 5934         0.764   0.744    1    -2.340       0.1810      0.010900  ...
# 5935         0.880   0.726   10    -5.855       0.2570      0.021800  ...
# 5936         0.743   0.516   11    -8.270       0.3970      0.028000  ...
# 5937         0.567   0.711    1    -4.899       0.3230      0.062600  ...
# 5938         0.401   0.872    0    -4.910       0.1170      0.215000  ...
#
#       Duration_ms                                              Title  \
# 0          222640         Gorillaz - Feel Good Inc. (Official Video)
# 1          200173  Gorillaz - Rhinestone Eyes [Storyboard Film] (...
# 2          215150  Gorillaz - New Gold ft. Tame Impala & Bootie B...
# 3          233867     Gorillaz - On Melancholy Hill (Official Video)
# 4          340920         Gorillaz - Clint Eastwood (Official Video)
# ...           ...                                                ...
# 5934       262213         Mase - Welcome Back (Official Music Video)
# 5935       271213  Mase [feat. Total] - What You Want (Official M...
# 5936       255160  Ma$e, Diddy: Lookin' At Me (EXPLICIT) [UP.S 4K...
# 5937       197480  Mase - Breath, Stretch, Shake (Official Music ...
# 5938       243000  Take Me There- Mya ft. Blackstreet, Mase, Blin...
#
#                     Channel        Views      Likes  Comments  \
# 0                  Gorillaz  693555221.0  6220896.0  169907.0
# 1                  Gorillaz   72011645.0  1079128.0   31003.0
# 2                  Gorillaz    8435055.0   282142.0    7399.0
# 3                  Gorillaz  211754952.0  1788577.0   55229.0
# 4                  Gorillaz  618480958.0  6197318.0  155930.0
# ...                     ...          ...        ...       ...
# 5934  Bad Boy Entertainment    8197484.0    87436.0    5699.0
# 5935  Bad Boy Entertainment   19975260.0   165989.0    3642.0
# 5936   REMASTERED HIPHOPâª      14135.0      399.0      28.0
# 5937        MASE TELEVISION     612044.0     7570.0     511.0
# 5938          MrILovethe90s     980948.0    14763.0    1267.0
#
#                                             Description  Licensed  \
# 0     Official HD Video for Gorillaz' fantastic trac...      True
# 1     The official video for Gorillaz - Rhinestone E...      True
# 2     Gorillaz - New Gold ft. Tame Impala & Bootie B...      True
# 3     Follow Gorillaz online:\nhttp://gorillaz.com \...      True
# 4     The official music video for Gorillaz - Clint ...      True
# ...                                                 ...       ...
# 5934  Official Music Video for Mase - "Welcome Back"...      True
# 5935  Official Music Video for Mase [feat. Total] - ...      True
# 5936  SUPPORT/DONATE/REQUEST: https://paypal.me/REMA...     False
# 5937  Courtesy Of Bad Boy Entertainment/Fo' Reel Ent...     False
# 5938  take me there off the rugrats movie soundtrack...     False
#
#       official_video        Stream
# 0               True  1.040235e+09
# 1               True  3.100837e+08
# 2               True  6.306347e+07
# 3               True  4.346636e+08
# 4               True  6.172597e+08
# ...              ...           ...
# 5934            True  2.354820e+07
# 5935            True  1.309991e+07
# 5936           False  1.006187e+07
# 5937           False  8.180179e+06
# 5938           False  8.443052e+06
#
# [5939 rows x 24 columns]

# %%
# checking missing values counts in each column of the dataframe

data.isna().sum()
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Title               119
# Channel             119
# Views               119
# Likes               146
# Comments            146
# Description         326
# Licensed            119
# official_video      119
# Stream              212
# dtype: int64

# %%
# filling the missing values with 0 in Likes & Commnets column

data['Likes'] =  data['Likes'].fillna(0)
data['Comments'] = data['Comments'].fillna(0)

# %%
data.isnull().sum()     # to check the count of missing values in each column
# Out:
# Artist                0
# Track                 0
# Album                 0
# Album_type            0
# Danceability          0
# Energy                0
# Key                   0
# Loudness              0
# Speechiness           0
# Acousticness          0
# Instrumentalness      0
# Liveness              0
# Valence               0
# Tempo                 0
# Duration_ms           0
# Title               119
# Channel             119
# Views               119
# Likes                 0
# Comments              0
# Description         326
# Licensed            119
# official_video      119
# Stream              212
# dtype: int64

# %%
data.dropna(inplace = True)               # It drops the rows that contains all or any missing values

# %%
data.isnull().sum()     # to check the count of missing values in each column
# Out:
# Artist              0
# Track               0
# Album               0
# Album_type          0
# Danceability        0
# Energy              0
# Key                 0
# Loudness            0
# Speechiness         0
# Acousticness        0
# Instrumentalness    0
# Liveness            0
# Valence             0
# Tempo               0
# Duration_ms         0
# Title               0
# Channel             0
# Views               0
# Likes               0
# Comments            0
# Description         0
# Licensed            0
# official_video      0
# Stream              0
# dtype: int64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5413 entries, 0 to 5938
# Data columns (total 24 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Artist            5413 non-null   object
#  1   Track             5413 non-null   object
#  2   Album             5413 non-null   object
#  3   Album_type        5413 non-null   object
#  4   Danceability      5413 non-null   float64
#  5   Energy            5413 non-null   float64
#  6   Key               5413 non-null   int64
#  7   Loudness          5413 non-null   float64
#  8   Speechiness       5413 non-null   float64
#  9   Acousticness      5413 non-null   float64
#  10  Instrumentalness  5413 non-null   float64
#  11  Liveness          5413 non-null   float64
#  12  Valence           5413 non-null   float64
#  13  Tempo             5413 non-null   float64
#  14  Duration_ms       5413 non-null   int64
#  15  Title             5413 non-null   object
#  16  Channel           5413 non-null   object
#  17  Views             5413 non-null   float64
#  18  Likes             5413 non-null   float64
#  19  Comments          5413 non-null   float64
#  20  Description       5413 non-null   object
#  21  Licensed          5413 non-null   object
#  22  official_video    5413 non-null   object
#  23  Stream            5413 non-null   float64
# dtypes: float64(13), int64(2), object(9)
# memory usage: 1.0+ MB

# %% [markdown]
# #### Q.1) Top 10 Artists - with the Highest Views on YouTube?

# %%
data.head(2)
# Out:
#      Artist            Track          Album Album_type  Danceability  Energy  \
# 0  Gorillaz   Feel Good Inc.     Demon Days      album         0.818   0.705
# 1  Gorillaz  Rhinestone Eyes  Plastic Beach      album         0.676   0.703
#
#    Key  Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0    6    -6.679       0.1770       0.00836  ...       222640
# 1    8    -5.815       0.0302       0.08690  ...       200173
#
#                                                Title   Channel        Views  \
# 0         Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
# 1  Gorillaz - Rhinestone Eyes [Storyboard Film] (...  Gorillaz   72011645.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
# 1  1079128.0   31003.0  The official video for Gorillaz - Rhinestone E...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
# 1      True            True  3.100837e+08
#
# [2 rows x 24 columns]

# %%
Artist_grouped =  data.groupby('Artist')['Views'].sum()

# %%
Artist_grouped
# Out:
# Artist
# *NSYNC           1.027833e+09
# 112              2.083818e+08
# 21 Savage        1.718228e+08
# 2Pac             1.092433e+09
# 3 Doors Down     1.527164e+09
#                      ...
# blink-182        1.451952e+09
# kevoxx           4.246572e+07
# mor ve Ã¶tesi    2.207599e+08
# thasup           7.073185e+07
# Ãejo            6.266808e+08
# Name: Views, Length: 590, dtype: float64

# %%
Artist_sorted =  Artist_grouped.sort_values(ascending = False)

# %%
Artist_sorted.head(10)
# Out:
# Artist
# Luis Fonsi            1.162798e+10
# Daddy Yankee          1.086828e+10
# Coldplay              9.997278e+09
# Eminem                9.119324e+09
# Enrique Iglesias      8.860271e+09
# Shakira               8.818140e+09
# Sia                   8.441835e+09
# Farruko               7.125613e+09
# Earth, Wind & Fire    6.414077e+09
# Nicky Jam             6.321868e+09
# Name: Views, dtype: float64

# %% [markdown]
# #### Q.2) Top 10 Tracks - with the Highest Streams on Spotify?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705    6
#
#    Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0    -6.679        0.177       0.00836  ...       222640
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
#
# [1 rows x 24 columns]

# %%
x = data[['Track', 'Stream']]          # creating a new dataframe with 2 columns - Track & Stream

x
# Out:
#                                                   Track        Stream
# 0                                        Feel Good Inc.  1.040235e+09
# 1                                       Rhinestone Eyes  3.100837e+08
# 2         New Gold (feat. Tame Impala and Bootie Brown)  6.306347e+07
# 3                                    On Melancholy Hill  4.346636e+08
# 4                                        Clint Eastwood  6.172597e+08
# ...                                                 ...           ...
# 5934                                       Welcome Back  2.354820e+07
# 5935                        What You Want (feat. Total)  1.309991e+07
# 5936                   Lookin' at Me (feat. Puff Daddy)  1.006187e+07
# 5937           Breathe, Stretch, Shake (feat. P. Diddy)  8.180179e+06
# 5938  Take Me There - From "The Rugrats Movie" Sound...  8.443052e+06
#
# [5413 rows x 2 columns]

# %%
most_stream_track =  x.sort_values(by = ['Stream'], ascending=False).head(10) # sorting the dataframe wrt Stream column

# %%
most_stream_track
# Out:
#                          Track        Stream
# 140       lovely (with Khalid)  2.110574e+09
# 43    Something Just Like This  2.030826e+09
# 1151         Despacito - Remix  1.593688e+09
# 569    Wonderwall - Remastered  1.568357e+09
# 124            Till I Collapse  1.548872e+09
# 254              Cheap Thrills  1.538447e+09
# 365                  Despacito  1.506598e+09
# 1147                 Despacito  1.506598e+09
# 40                      Yellow  1.483622e+09
# 1777      Don't Stop Believin'  1.466430e+09

# %% [markdown]
# #### Q.3) What are the most common Album Types on Spotify? How many tracks belong to each album type?

# %%
data.head(1)
# Out:
#      Artist           Track       Album Album_type  Danceability  Energy  Key  \
# 0  Gorillaz  Feel Good Inc.  Demon Days      album         0.818   0.705    6
#
#    Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 0    -6.679        0.177       0.00836  ...       222640
#
#                                         Title   Channel        Views  \
# 0  Gorillaz - Feel Good Inc. (Official Video)  Gorillaz  693555221.0
#
#        Likes  Comments                                        Description  \
# 0  6220896.0  169907.0  Official HD Video for Gorillaz' fantastic trac...
#
#    Licensed  official_video        Stream
# 0      True            True  1.040235e+09
#
# [1 rows x 24 columns]

# %%
data.Album_type.unique()              # to check the unique values in a column
# Out:
# array(['album', 'single', 'compilation'], dtype=object)

# %%
a_type =  data['Album_type'].value_counts()     # It shows all unique values with their counts in the column

a_type
# Out:
# Album_type
# album          4447
# single          638
# compilation     328
# Name: count, dtype: int64

# %%
# drawing a Pie chart

plt.pie( a_type, labels =  a_type.index, autopct = "‘%1.1f%%’", startangle= 60 ,
        colors= 'myr', shadow='True', explode = (0.05,0.05,0.05),  pctdistance = 0.75)

plt.show()

# %% [markdown]
# #### Q.4) How do the Average Views, Likes, and Comments are compared between different Album Types?

# %%
# group the Album Type column, and show the mean of three columns

df = data.groupby('Album_type')[['Likes', 'Views', 'Comments']].mean()

df
# Out:
#                      Likes         Views      Comments
# Album_type
# album        526701.773555  9.389342e+07  19069.521475
# compilation  453737.478659  7.407717e+07  17490.356707
# single       557707.617555  7.627789e+07  18338.426332

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df = df.reset_index()                # rest_index - To convert the index of a Series into a column to form a DataFrame

df
# Out:
#     Album_type          Likes         Views      Comments
# 0        album  526701.773555  9.389342e+07  19069.521475
# 1  compilation  453737.478659  7.407717e+07  17490.356707
# 2       single  557707.617555  7.627789e+07  18338.426332

# %%
# melt - unpivot a dataframe

df_melted  = pd.melt( df, id_vars = 'Album_type', var_name = "Attribute", value_name = 'Total' )

df_melted
# Out:
#     Album_type Attribute         Total
# 0        album     Likes  5.267018e+05
# 1  compilation     Likes  4.537375e+05
# 2       single     Likes  5.577076e+05
# 3        album     Views  9.389342e+07
# 4  compilation     Views  7.407717e+07
# 5       single     Views  7.627789e+07
# 6        album  Comments  1.906952e+04
# 7  compilation  Comments  1.749036e+04
# 8       single  Comments  1.833843e+04

# %%
# Drawing the Bar Plot

plt.figure(figsize = (9,4))

sns.barplot( x = 'Album_type', y = 'Total', hue = 'Attribute', data = df_melted );

# %% [markdown]
# #### Q.5) Top 5 YouTube Channels -  based on the Views?

# %%
c_views = data.groupby('Channel')['Views'].sum().sort_values(ascending=False).head()

c_views
# Out:
# Channel
# LuisFonsiVEVO          1.945685e+10
# T-Series               1.494441e+10
# EminemVEVO             8.810791e+09
# EnriqueIglesiasVEVO    8.729674e+09
# shakiraVEVO            8.421020e+09
# Name: Views, dtype: float64

# %%
c_views = c_views.reset_index()

c_views.head(10)
# Out:
#                Channel         Views
# 0        LuisFonsiVEVO  1.945685e+10
# 1             T-Series  1.494441e+10
# 2           EminemVEVO  8.810791e+09
# 3  EnriqueIglesiasVEVO  8.729674e+09
# 4          shakiraVEVO  8.421020e+09

# %%
type(c_views)
# Out:
# pandas.core.frame.DataFrame

# %%
# sns.set_style("whitegrid")

sns.barplot( x = "Views", y = "Channel", data = c_views, color='black')
plt.title('Top 5 Channels by Views')
plt.xlabel('Views')
plt.ylabel('Channel')
plt.show()

# %% [markdown]
# #### Q.6) The Top Most Track -  based on Views?

# %%
data.sort_values( by = 'Views', ascending = False).head(1)
# Out:
#           Artist      Track Album Album_type  Danceability  Energy  Key  \
# 1147  Luis Fonsi  Despacito  VIDA      album         0.655   0.797    2
#
#       Loudness  Speechiness  Acousticness  ...  Duration_ms  \
# 1147    -4.787        0.153         0.198  ...       229360
#
#                                         Title        Channel         Views  \
# 1147  Luis Fonsi - Despacito ft. Daddy Yankee  LuisFonsiVEVO  8.079649e+09
#
#            Likes   Comments  \
# 1147  50788652.0  4252791.0
#
#                                             Description  Licensed  \
# 1147  âDespacitoâ disponible ya en todas las pla...      True
#
#       official_video        Stream
# 1147            True  1.506598e+09
#
# [1 rows x 24 columns]

# %% [markdown]
# #### Q.7) Which Top 7 Tracks have the highest Like-to-View ratio on YouTube?

# %%
track_lv = data[['Track', 'Likes', 'Views']]

track_lv
# Out:
#                                                   Track      Likes  \
# 0                                        Feel Good Inc.  6220896.0
# 1                                       Rhinestone Eyes  1079128.0
# 2         New Gold (feat. Tame Impala and Bootie Brown)   282142.0
# 3                                    On Melancholy Hill  1788577.0
# 4                                        Clint Eastwood  6197318.0
# ...                                                 ...        ...
# 5934                                       Welcome Back    87436.0
# 5935                        What You Want (feat. Total)   165989.0
# 5936                   Lookin' at Me (feat. Puff Daddy)      399.0
# 5937           Breathe, Stretch, Shake (feat. P. Diddy)     7570.0
# 5938  Take Me There - From "The Rugrats Movie" Sound...    14763.0
#
#             Views
# 0     693555221.0
# 1      72011645.0
# 2       8435055.0
# 3     211754952.0
# 4     618480958.0
# ...           ...
# 5934    8197484.0
# 5935   19975260.0
# 5936      14135.0
# 5937     612044.0
# 5938     980948.0
#
# [5413 rows x 3 columns]

# %%
track_lv['LV_Ratio'] = track_lv['Likes']/track_lv['Views'] * 100
# Out:
# /tmp/ipython-input-136-4232201996.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   track_lv['LV_Ratio'] = track_lv['Likes']/track_lv['Views'] * 100

# %%
track_lv
# Out:
#                                                   Track      Likes  \
# 0                                        Feel Good Inc.  6220896.0
# 1                                       Rhinestone Eyes  1079128.0
# 2         New Gold (feat. Tame Impala and Bootie Brown)   282142.0
# 3                                    On Melancholy Hill  1788577.0
# 4                                        Clint Eastwood  6197318.0
# ...                                                 ...        ...
# 5934                                       Welcome Back    87436.0
# 5935                        What You Want (feat. Total)   165989.0
# 5936                   Lookin' at Me (feat. Puff Daddy)      399.0
# 5937           Breathe, Stretch, Shake (feat. P. Diddy)     7570.0
# 5938  Take Me There - From "The Rugrats Movie" Sound...    14763.0
#
#             Views  LV_Ratio
# 0     693555221.0  0.896958
# 1      72011645.0  1.498547
# 2       8435055.0  3.344874
# 3     211754952.0  0.844645
# 4     618480958.0  1.002022
# ...           ...       ...
# 5934    8197484.0  1.066620
# 5935   19975260.0  0.830973
# 5936      14135.0  2.822780
# 5937     612044.0  1.236839
# 5938     980948.0  1.504973
#
# [5413 rows x 4 columns]

# %%
track_lv.sort_values( by = 'LV_Ratio', ascending = False).head(7)
# Out:
#                                                   Track    Likes     Views  \
# 1520                    r()t()nda (feat. Tiziano Ferro)  11048.0   91142.0
# 2552                               Castles Made of Sand  12703.0  131571.0
# 5462                                Enter the Metaverse     25.0     275.0
# 1067                                               Raid  86055.0  986916.0
# 757                           Toc Toc (feat. Timbaland)  70607.0  878121.0
# 5146  Mozart: Concerto For Clarinet And Orchestra In...     23.0     293.0
# 5300                                      Bars of Death   4933.0   65692.0
#
#        LV_Ratio
# 1520  12.121744
# 2552   9.654863
# 5462   9.090909
# 1067   8.719587
# 757    8.040691
# 5146   7.849829
# 5300   7.509286

# %% [markdown]
# #### Q.8) Top Albums having the Tracks with Maximum Danceability ?

# %%
# creating groups for each Album

T_danceability =  data.groupby('Album')['Danceability'].sum().sort_values(ascending=False)

T_danceability
# Out:
# Album
# Greatest Hits                                             11.6160
# The Score (Expanded Edition)                              10.5630
# I Am L.V.                                                  7.5600
# Madvillainy                                                6.9190
# Folge 152: und das Geheimnis der Kelly BrÃ¼der             6.2580
#                                                            ...
# Mozart: Requiem / Exultate, Jubilate / Laudate Dominum     0.0690
# The Greatest Video Game Music 2                            0.0673
# Barber: Adagio for Strings                                 0.0640
# Israeli Salad                                              0.0000
# Hello, Dolly! (Remastered)                                 0.0000
# Name: Danceability, Length: 3502, dtype: float64

# %%
data[data.Album == 'Greatest Hits']          # filtering the dataframe with 'Greatest Hits'
# Out:
#                                Artist  \
# 220                              2Pac
# 222                              2Pac
# 225                              2Pac
# 268                     Fleetwood Mac
# 1232                Bruce Springsteen
# 1236                Bruce Springsteen
# 1862                     Shania Twain
# 2164                      Wyclef Jean
# 3079                    Tracy Chapman
# 3097                          Blondie
# 3578                       Eurythmics
# 3579                       Eurythmics
# 3580                       Eurythmics
# 3598                      Snow Patrol
# 3836                     James Taylor
# 3842                     James Taylor
# 4324  Tom Petty and the Heartbreakers
# 5185                   Gloria Estefan
#
#                                                   Track          Album  \
# 220                         Hit 'Em Up - Single Version  Greatest Hits
# 222                  California Love - Original Version  Greatest Hits
# 225                                             Changes  Greatest Hits
# 268                                               Gypsy  Greatest Hits
# 1232              Streets of Philadelphia - Single Edit  Greatest Hits
# 1236                                      Secret Garden  Greatest Hits
# 1862          From This Moment On - Pop On-Tour Version  Greatest Hits
# 2164                    Killing Me Softly With His Song  Greatest Hits
# 3079  Stand by Me - Live at the Late Show with David...  Greatest Hits
# 3097                                              Maria  Greatest Hits
# 3578                    Sweet Dreams (Are Made of This)  Greatest Hits
# 3579     There Must Be an Angel (Playing With My Heart)  Greatest Hits
# 3580                                    Miracle of Love  Greatest Hits
# 3598                                       Just Say Yes  Greatest Hits
# 3836                                Carolina in My Mind  Greatest Hits
# 3842                     Something in the Way She Moves  Greatest Hits
# 4324                             Mary Jane's Last Dance  Greatest Hits
# 5185                                              Conga  Greatest Hits
#
#        Album_type  Danceability  Energy  Key  Loudness  Speechiness  \
# 220   compilation         0.916   0.844    7    -3.967       0.2360
# 222   compilation         0.763   0.850    7    -3.052       0.0417
# 225   compilation         0.865   0.665    7    -6.289       0.0730
# 268   compilation         0.622   0.540    5   -13.990       0.0261
# 1232  compilation         0.741   0.290    5   -13.251       0.0302
# 1236  compilation         0.520   0.329    0   -14.224       0.0266
# 1862  compilation         0.460   0.505    9    -5.487       0.0266
# 2164  compilation         0.765   0.437    4   -10.122       0.0727
# 3079  compilation         0.816   0.144    7   -10.148       0.0398
# 3097  compilation         0.548   0.800    9    -6.926       0.0597
# 3578  compilation         0.710   0.472    8   -15.985       0.0498
# 3579  compilation         0.545   0.663    0   -11.360       0.0455
# 3580  compilation         0.529   0.472    2   -12.526       0.0264
# 3598  compilation         0.535   0.883    9    -5.456       0.0330
# 3836  compilation         0.579   0.267    4   -15.110       0.0348
# 3842  compilation         0.447   0.186    0   -17.369       0.0322
# 4324  compilation         0.464   0.655    7    -9.058       0.0608
# 5185  compilation         0.791   0.860    2    -8.282       0.0451
#
#       Acousticness  ...  Duration_ms  \
# 220         0.0394  ...       312627
# 222         0.0304  ...       284907
# 225         0.0453  ...       268827
# 268         0.0170  ...       264907
# 1232        0.2940  ...       195080
# 1236        0.5760  ...       266613
# 1862        0.4200  ...       235107
# 2164        0.0271  ...       290293
# 3079        0.7970  ...       169013
# 3097        0.0380  ...       249427
# 3578        0.2960  ...       293133
# 3579        0.3560  ...       280360
# 3580        0.3130  ...       275000
# 3598        0.0214  ...       281987
# 3836        0.1180  ...       238573
# 3842        0.2830  ...       189480
# 4324        0.0272  ...       273600
# 5185        0.1180  ...       255760
#
#                                                   Title               Channel  \
# 220          2Pac - Hit 'Em Up (Dirty) (Music Video) HD         Seven Hip-Hop
# 222   2Pac ft. Dr. Dre - California Love (Official V...          UPROXX Video
# 225                 2pac - Changes Original Music Video              The Best
# 268        Fleetwood Mac - Gypsy (Official Music Video)         Fleetwood Mac
# 1232  Bruce Springsteen - Streets of Philadelphia (O...  BruceSpringsteenVEVO
# 1236  Bruce Springsteen Secret Garden HD, Jerry Magu...                    VJ
# 1862          From This Moment On (Pop On-Tour Version)  Shania Twain - Topic
# 2164  Fugees - Killing Me Softly With His Song (Offi...         TheFugeesVEVO
# 3079  Tracy Chapman - Stand by Me (Live on Letterman...  Tracy Chapman Online
# 3097                                    Maria - Blondie             Paola1311
# 3578  Eurythmics, Annie Lennox, Dave Stewart - Sweet...        EurythmicsVEVO
# 3579  There Must Be An Angel (Playing With My Heart)...        EurythmicsVEVO
# 3580  Eurythmics, Annie Lennox, Dave Stewart - Mirac...        EurythmicsVEVO
# 3598        Snow Patrol - Just Say Yes (Official Video)        SnowPatrolVEVO
# 3836   Carolina In My Mind - James Taylor - Lyrics / HD         Roadvideo 404
# 3842  James Taylor - Something In The Way She Moves ...          James Taylor
# 4324  Tom Petty And The Heartbreakers - Mary Jane's ...          TomPettyVEVO
# 5185        Gloria Estefan, Miami Sound Machine - Conga     GloriaEstefanVEVO
#
#             Views      Likes  Comments  \
# 220   585712131.0  4363164.0  208460.0
# 222    84654029.0   484619.0   12875.0
# 225      306542.0     4350.0     305.0
# 268    81512369.0   436530.0   17764.0
# 1232  171514802.0   669935.0   25407.0
# 1236   25696359.0   104022.0    4674.0
# 1862    2629831.0    30669.0      65.0
# 2164  351401822.0  2549466.0   42859.0
# 3079   16971605.0   134753.0       0.0
# 3097   70126379.0   263063.0    9124.0
# 3578  763534682.0  6430665.0  221508.0
# 3579   37150247.0   248173.0   10256.0
# 3580   31391217.0   219858.0    7682.0
# 3598   36198740.0   124427.0    5415.0
# 3836    1774157.0    14808.0     879.0
# 3842     404157.0     5941.0     249.0
# 4324   43989902.0   294874.0   12666.0
# 5185   31857094.0   330290.0   11886.0
#
#                                             Description  Licensed  \
# 220   Music video by 2Pac performing Hit 'Em Up (Dir...     False
# 222   2Pac ft. Dr. Dre - California Love (Full Video...     False
# 225                 2pac - Changes Original Music Video     False
# 268   You're watching the official music video for F...      True
# 1232  Official Video of âStreets Of Philadelphia" ...      True
# 1236  My music video of Bruce Springsteen's beautifu...     False
# 1862  Provided to YouTube by Universal Music Group\n...      True
# 2164  "Killing Me Softly With His Song" by Fugees\n\...      True
# 3079  â¥ Subscribe our newsletter âº https://www.a...     False
# 3097                                     Blondie, Maria     False
# 3578  Eurythmics -Â Sweet Dreams (Are Made Of This) ...      True
# 3579  Eurythmics - There Must Be An Angel (Playing W...      True
# 3580  Eurythmics - Miracle Of Love (Official Video)\...      True
# 3598  Snow Patrol - Just Say Yes (Official Video)\n\...      True
# 3836                Disclaimer : For Entertainment Only     False
# 3842  In this restored footage James performs his so...      True
# 4324  REMASTERED IN HD!\n\nMusic video by Tom Petty ...      True
# 5185  Watch the official music video for "Conga" by ...      True
#
#       official_video       Stream
# 220            False  375955728.0
# 222            False  497213287.0
# 225            False  411056377.0
# 268             True  213673856.0
# 1232            True  239663934.0
# 1236           False   69059523.0
# 1862            True   84623227.0
# 2164            True  518080621.0
# 3079           False   44060055.0
# 3097           False   90857487.0
# 3578            True   14943362.0
# 3579            True   63464225.0
# 3580            True   38401127.0
# 3598            True   72665878.0
# 3836           False  113315832.0
# 3842            True   31811854.0
# 4324            True  256341255.0
# 5185            True  199693647.0
#
# [18 rows x 24 columns]

# %% [markdown]
# #### Q.9) What is the Correlation between Views, Likes, Comments, and Stream?

# %%
# creating a new dataframe with 4 columns

df_vlcs = data[['Views', 'Likes', 'Comments', 'Stream']]

df_vlcs
# Out:
#             Views      Likes  Comments        Stream
# 0     693555221.0  6220896.0  169907.0  1.040235e+09
# 1      72011645.0  1079128.0   31003.0  3.100837e+08
# 2       8435055.0   282142.0    7399.0  6.306347e+07
# 3     211754952.0  1788577.0   55229.0  4.346636e+08
# 4     618480958.0  6197318.0  155930.0  6.172597e+08
# ...           ...        ...       ...           ...
# 5934    8197484.0    87436.0    5699.0  2.354820e+07
# 5935   19975260.0   165989.0    3642.0  1.309991e+07
# 5936      14135.0      399.0      28.0  1.006187e+07
# 5937     612044.0     7570.0     511.0  8.180179e+06
# 5938     980948.0    14763.0    1267.0  8.443052e+06
#
# [5413 rows x 4 columns]

# %%
df_vlcs.corr()                      # correlation matrix for the required columns
# Out:
#              Views     Likes  Comments    Stream
# Views     1.000000  0.944568  0.849723  0.545580
# Likes     0.944568  1.000000  0.898619  0.571299
# Comments  0.849723  0.898619  1.000000  0.370450
# Stream    0.545580  0.571299  0.370450  1.000000

# %%
sns.heatmap(df_vlcs.corr())            # drawing a heatmap for the correlation matrix
# Out:
# <Axes: >
